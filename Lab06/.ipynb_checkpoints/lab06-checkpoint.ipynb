# %% [markdown]
# # Shazam do GTZAN
#
# **Objetivos**
# 1. Entender o Shazam!
#
# **Resultado Esperado**
# 1. Saber criar um índice de constelações
# 1. Realizar consultas no mesmo
#
# **Caso queira indexar tudo, recomendo o uso da biblioteca sparse, descomente abaixo**

# %%
# !pip install sparse
import sparse

# %%
from numba import jit

import librosa
import librosa.display

import IPython.display as ipd

import matplotlib.pyplot as plt

import numpy as np
import os
import pandas as pd

plt.rcParams['axes.labelsize']  = 16
plt.rcParams['axes.titlesize']  = 16
plt.rcParams['legend.fontsize'] = 16
plt.rcParams['xtick.labelsize'] = 16
plt.rcParams['ytick.labelsize'] = 16
plt.rcParams['lines.linewidth'] = 2

plt.ion()

# %% [markdown]
# ## Introdução
#
# Neste notebook vamos tentar montar um [Shazam](https://shazam.com). Criado em meados de 2003 \[[1](https://www.ee.columbia.edu/~dpwe/papers/Wang03-shazam.pdf)\], o Shazam é um serviço que identifica músicas com base em clipes pequenos. No começo dos anos 2010s, o advento de aplicativos de celulares popularizou o serviço Shazam. Com o passar dos anos, as ideias do Shazam foram copiadas por empresas como a Google a Apple, que incluem variações do serviço de descoberta nos seus sistemas operacionais Android e IOs. Se não me engano, a Apple usa APIs do Shazam, enquanto a Google tem sua versões própria.
#
# ![](https://digitalagencynetwork.com/wp-content/uploads/2017/12/confirmed-apple-bought-shazam-app-reasonable-point.jpg)
#
# O funcionamento do Shazam é feito através da técnica de *audio fingerprinting*. Aqui, um índice invertido de atributos musicais é criado. Com tal índice, podemos rapidamente identificar uma música através de um clipe pequeno da mesma. A figura abaixo mostra a ideia de como um serviço seria implementado no mundo real. Aqui, vamos fazer uma versão simples em memória.
#
# ![Audio Finger](https://www.audiolabs-erlangen.de/resources/MIR/FMP/data/C7/FMP_C7_F02.png)

# %% [markdown]
# ## Base de Dados
#
# Para nossa tarefa, vamos fazer uso da base GTZAN. A base GTZAN é composta por 1.000 trechos de música e áudio de meio minuto, classificados individualmente em dez categorias. Por hora, vamos ignorar as categorias e focar apenas nas músicas. Para um melhor entendimento do GTZAN leia a referência \[[2](https://arxiv.org/pdf/1306.1461.pdf)\].
#
# ### A base de dados que será indexada (GTZAN)
#
# Toda a base GTZAN pode ser encontrada no [Kaggle](https://www.kaggle.com/andradaolteanu/gtzan-dataset-music-genre-classification). Caso necessite, uma versão também pode ser encontrada no drive junto deste notebook.
#
# Abaixo mostramos as pastas e arquivos do GTZAN. Tais músicas vem no formato wav. Sua tarefa será montar um índice de um **subconjunto** de tais músicas. Já explico.

# %%
# !ls Data/genres_original
# Out:
# blues  classical  country  disco  hiphop  jazz	metal  pop  reggae  rock

# %%
# !ls Data/genres_original/blues | head
# Out:
# blues.00000.wav
# blues.00001.wav
# blues.00002.wav
# blues.00003.wav
# blues.00004.wav
# blues.00005.wav
# blues.00006.wav
# blues.00007.wav
# blues.00008.wav
# blues.00009.wav

# %% [markdown]
# ### A base de dados de consulta (MIREX-2020)
#
# Como sua tarefa é montar um Shazam, precisamos de uma base de consultas. Desde 2005, a [Music Information Retrieval Evaluation eXchange (MIREX 2020)](https://www.music-ir.org/mirex) organia competições no tema de recuperação de informação musical. Já fazem alguns anos, desde 2013, onde anualmente uma das competições do MIREX é no tema de *audio fingerprinting* (nossa tarefa). O link ao lado contém a descrição da tarefa [Audio Fingerprinting MIREX 2020](https://www.music-ir.org/mirex/wiki/2020:Audio_Fingerprinting).
#
# Para simular o uso do Shazam, junto com tal competição, uma base de dados de consultas é fornecida. Tal base foi gravada em telefones celulares em diferentes ambientes. Para entender o formato de tal base, segue uma lista dos arquivos.

# %%
# !ls -l mir-2013-GeorgeDataset_snippet\(10sec\)_1062
# Out:
# total 921860
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00005-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00039-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00040-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00050-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 blues.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00005-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00039-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00049-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00050-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 Classical.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 Classical.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 Classical.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 classical.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00004-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00049-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 country.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884110 jul 27  2014 disco.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 882062 jul 27  2014 disco.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 883246 jul 27  2014 disco.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00040-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 disco.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884110 jul 27  2014 hiphop.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00040-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00049-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00050-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 hiphop.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00004-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00039-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 jazz.00084-snippet-10-10.wav
# ...
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 pop.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00005-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 882062 jul 27  2014 reggae.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00039-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 reggae.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 883246 jul 27  2014 reggae.00085-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00000-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00000-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00000-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00003-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00003-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00003-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00004-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00004-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00005-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00005-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00009-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00009-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00009-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00010-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00010-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00010-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00011-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00011-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00011-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00012-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00012-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00012-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00013-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00013-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00013-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00014-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00014-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00014-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00015-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00015-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00015-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00019-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00019-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00019-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00020-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00020-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00020-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00024-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00024-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00024-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00025-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00025-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00025-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00034-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00034-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00034-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00035-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00035-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00035-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00039-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00039-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00039-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00040-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00040-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00044-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00044-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00044-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00045-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00045-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00045-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00049-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00049-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00050-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00050-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00054-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00054-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00054-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00055-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00055-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00055-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00059-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00059-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00059-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00060-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00060-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00060-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00064-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00064-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00064-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00065-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00065-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00065-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00069-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00069-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00069-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00070-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00070-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00070-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00074-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00074-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00074-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00075-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00075-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00075-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00079-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00079-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00079-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00080-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00080-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00080-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00084-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00084-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00084-snippet-10-20.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00085-snippet-10-0.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00085-snippet-10-10.wav
# -rw-rw-r-- 1 cadar cadar 884782 jul 27  2014 rock.00085-snippet-10-20.wav

# %% [markdown]
# Observe como cada arquivo corresponde a uma música do GTZAN. Além do mais, três clipes de 10 segundos são fornecidos por música. Por exemplos, a música `blues.00000.wav`do GTZAN tem como respostas os clipes: `blues.00000-snippet-10-0.wav`, `blues.00000-snippet-10-10.wav`, `blues.00000-snippet-10-20.wav`.

# %% [markdown]
# ## Sua Tarefa
#
# Sabendo das bases acima, sua tarefa será em indexar e mensurar a Precision@1 (fração de acertos na primeira posição retornada) das músicas acima. **Por questões de memória limitada, você pode indexar apenas as músicas de consulta, não precisa indexar todo GTZAN. Faça tudo na memória principal mesmo**.
#
# Para realizar sua tarefa crie mapas de constetalação das músicas e da consulta.
#
# ![](data:image/png;base64,...)

# %% [markdown]
# ### *Importante*: Fourier no GTZAN
#
# No GTZAN, cada música é gravada a uma taxa de amostragem de 22,05 kHz e arquivos de áudio mono de 16 bits no formato `.wav`. *Como toda música tem a mesma taxa de amostragem, os índices discretos da transformada de Fourier são os mesmos para todas as músicas. ELAS JÁ VEM BINARIZADAS NO EIXO-Y do mapa de constelação*.

# %% [markdown]
# ## Carregando os Espectrogramas
#
# O código abaixo carrega os espectrogramas. Coloquei também um função que plota os mesmos.

# %%
import warnings
warnings.filterwarnings('ignore')

def plot_spec(stft, sr, constelation=None):
    fig, ax = plt.subplots(figsize=(1.618 * 16, 16))
    img = librosa.display.specshow(librosa.amplitude_to_db(stft, ref=np.max),
                                   y_axis='log',
                                   x_axis='time',
                                   hop_length=sr,
                                   ax=ax)
    fig.colorbar(img, ax=ax, format="%+2.0f dB")
    if constelation is not None and constelation.any():
        x, y = np.where(constelation)
        ax.scatter(x, y, s=100, alpha=0.8, color='red')
    fig.show()

# %% [markdown]
# **Observe como passo o `hop_length=sr` no stft**. Como estou com uma música com taxa SR por segundo, tiro a média a cada SR frames. Isso deixa meu espectrograma em SEGUNDOS. Algumas musicas passam um pouco de 30 segundos, portanto pego os trinta na marra.

# %%
def my_stft(wave, sr):
    stft_complex = librosa.stft(wave, hop_length=sr) # deve ter approx 30 secs
    stft = np.abs(stft_complex) # tira a norma do real e imag
    return stft[:, :30] # força 30 secs

# %%
wave, sr = librosa.load('Data/genres_original/blues/blues.00001.wav',
                        mono=True)
stft = my_stft(wave, sr)
plot_spec(stft, sr)
stft.shape
# Out:
# (1025, 30)

# %% [markdown]
# ### Mapa de Constelação
#
# O mapa pode ser implementado com a chamada: https://docs.scipy.org/doc/scipy/reference/generated/scipy.ndimage.maximum_filter.html. O `mode='constant'` faz um preenchimento nas bordas para garantir que tudo funcione. O `size` diz o tamanho do filtro que vamos usar.

# %%
from scipy import ndimage

def constellation_map(stft, kappa=7, tau=7, thresh=0.01):
    result = ndimage.maximum_filter(stft, size=[2*kappa+1, 2*tau+1], mode='constant')
    C = np.logical_and(stft == result, result > thresh)
    return C

# %%
constelation = constellation_map(stft, kappa=2, tau=2)
plot_spec(stft, sr, constelation)

# %% [markdown]
# ## Índice
#
# Observe como cada consulta precisa ser comparada com todas as seções (tendo a mesma duração da consulta) de todas as músicas contidas no base de dados. Tal estratégia de busca exaustiva, cujo tempo de execução depende linearmente do número e do tamanho da base de dados, não é viável. Portanto você deve implementar um índice como visto em sala de aula. A função `match_query_gtzan` lhe ajuda a carregar apenas os arquivos que existem na base de consultas.

# %%
import glob
import os

def match_query_gtzan():
    rv = {}
    path = os.path.join('mir-2013-GeorgeDataset_snippet(10sec)_1062', '*.wav')
    for wav_fpath in glob.glob(path):
        file_name = os.path.basename(wav_fpath)
        file_name_gztan = '{}{}'.format(file_name.split('-')[0], '.wav')
        genre = file_name_gztan.split('.')[0]
        rv[wav_fpath] = os.path.join('Data', 'genres_original', genre, file_name_gztan)
    return rv
matches = match_query_gtzan()
print(list(matches.items())[:10])
# Out:
# [('mir-2013-GeorgeDataset_snippet(10sec)_1062/classical.00039-snippet-10-0.wav', 'Data/genres_original/classical/classical.00039.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/disco.00040-snippet-10-10.wav', 'Data/genres_original/disco/disco.00040.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/blues.00070-snippet-10-10.wav', 'Data/genres_original/blues/blues.00070.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/country.00084-snippet-10-0.wav', 'Data/genres_original/country/country.00084.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/country.00025-snippet-10-20.wav', 'Data/genres_original/country/country.00025.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/jazz.00074-snippet-10-0.wav', 'Data/genres_original/jazz/jazz.00074.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/rock.00000-snippet-10-0.wav', 'Data/genres_original/rock/rock.00000.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/hiphop.00015-snippet-10-10.wav', 'Data/genres_original/hiphop/hiphop.00015.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/blues.00060-snippet-10-0.wav', 'Data/genres_original/blues/blues.00060.wav'), ('mir-2013-GeorgeDataset_snippet(10sec)_1062/rock.00003-snippet-10-20.wav', 'Data/genres_original/rock/rock.00003.wav')]

# %%
from collections import defaultdict
from tqdm import tqdm

def invertedList(constelation):
    d = defaultdict(lambda: [])
    for point in zip(*constelation.nonzero()): 
        if not (point[0] in d):
            d[point[0]] = []

        d[point[0]].append(point[1])
    for key in d:
        d[key] = np.array(d[key])
    return d

def index(colecao_de_stfts, kappa, tau):
    database = {}
    for filename in tqdm(colecao_de_stfts):
        
        try:
            wave, sr = librosa.load(filename, mono=True)
        except:
            print(f'error reading {filename}')
            continue

        stft = my_stft(wave, sr)
        constelation = constellation_map(stft, kappa=kappa, tau=tau)
        database[filename] = invertedList(constelation)
    return database
        
        
database = index(matches.values(), kappa=5, tau=5)
# Out:
#  14%|█▍        | 147/1062 [00:00<00:03, 291.44it/s]
# error reading Data/genres_original/jazz/jazz.00054.wav
# error reading Data/genres_original/Classical/Classical.00074.wav
#  19%|█▉        | 207/1062 [00:01<00:05, 149.23it/s]
# error reading Data/genres_original/Classical/Classical.00074.wav
#  66%|██████▌   | 701/1062 [00:03<00:01, 193.47it/s]
# error reading Data/genres_original/jazz/jazz.00054.wav
#  76%|███████▌  | 802/1062 [00:03<00:01, 165.54it/s]
# error reading Data/genres_original/jazz/jazz.00054.wav
#  82%|████████▏ | 876/1062 [00:04<00:01, 173.27it/s]
# error reading Data/genres_original/Classical/Classical.00074.wav
# 100%|██████████| 1062/1062 [00:04<00:00, 221.75it/s]

# %%
kappa=5
tau=5

correct = np.zeros(len(matches))

for idx, filename in tqdm(enumerate(matches), total=len(matches)):    
    try:
        wave, sr = librosa.load(filename, mono=True)
    except:
        print(f'error reading {filename}')
        continue

    stft = my_stft(wave, sr)
    constelation = constellation_map(stft, kappa=kappa, tau=tau)
    
    max_matching_funcion = 0
    db_correspondence = ""
    
    for db_key in database.keys():
        matching_function = defaultdict(lambda: 0)
        db_entry = database[db_key]
        
        for point in zip(*constelation.nonzero()):
            h, n = point
            lh_n = db_entry[h] - n
            for i in lh_n:
                matching_function[i] = 1 + matching_function[i]
            
        max_pos = 0
        max_val = matching_function[0]
        
        for i in matching_function:
            if max_val < matching_function[i]:
                max_val = matching_function[i]
                max_pos = i
                
        if max_matching_funcion < max_val:
            max_matching_funcion = max_val
            db_correspondence = db_key

    correct[idx] = db_correspondence == matches[filename]

print(np.sum(correct)/len(correct))
#     print("--------------------------------------------------------")
#     print(f"Filename: {filename}")
#     print(f"Found Match: {db_correspondence}")
#     print(f"Correct Match: {matches[filename]}")
# Out:
# 100%|██████████| 1062/1062 [08:41<00:00,  2.04it/s]
# 0.09227871939736347

# %% [markdown]
# ## Problemas
#
# 1. Implemente o índice acima. É possível implementar o mesmo na memória. Use estruturas python ou uma matriz esparsa 3d (um tensor). Veja a descrição do lab. Da para fazer sem o sparse, mas não deve funcionar na base toda.
# 1. Realize as consultas e mensure o seu valor de precision@1
# 1. Qual o efeito do kappa e do tau no seu resultado?
# 1. Mude seu código para funciona na base toda (*extra*)
